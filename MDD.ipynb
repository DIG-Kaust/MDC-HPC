# %% [markdown]
# # MDD

# %% [markdown]
# ### Author: M.Ravasi

# %% [markdown]
# This notebook performs Multi-dimensional deconvolution (MDD) on the retrived 3D Green's functions to produce a local target reflectivity response $R$

# %% [markdown]
# In this context MDD can be written as
#
# $$\mathbf{g^-}= \mathbf{G^+} \mathbf{R}$$
#
# where $\mathbf{G^+}$ is the MDC operator created using the retrieved downgoing GF's while $\mathbf{g^+}$ is our data that contains the retrieved upgoing GF's. Both set of GF's can be computed upfront by running the ``Marchenko3D.sh`` script.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import dask.array as da
import pylops
import pylops_distributed

from scipy.sparse import csr_matrix, vstack
from scipy.linalg import lstsq, solve
from scipy.sparse.linalg import LinearOperator, cg, lsqr
from scipy import misc
from dask.distributed import Scheduler, Client

from pylops.utils.wavelets             import *
from pylops.utils.seismicevents        import *
from pylops.utils.tapers               import *

from pylops.utils import dottest
from pylops_distributed.utils import dottest as ddottest
from pylops_distributed.optimization.cg import cg as dcg
from pylops_distributed.optimization.cg import cgls as dcgls

# %%
os.environ["STORE_PATH"] = "/project/fsenter/mrava/Marchenko3D/"

# %% [markdown]
# Setup SSH cluster

# %%
client = pylops_distributed.utils.backend.dask(hardware='multi', client='be-linrgsn047:8786')
client
# Out:
# <Client: scheduler='tcp://10.224.36.70:8786' processes=9 cores=108>

# %%
client.restart()
# Out:
# <Client: scheduler='tcp://10.224.36.70:8786' processes=8 cores=96>

# %%
nworkers = len(np.array(list(client.ncores().values())))
ncores = np.sum(np.array(list(client.ncores().values())))
print('Nworkers', nworkers)
print('Ncores', ncores)
# Out:
# Nworkers 9
# Ncores 108

# %% [markdown]
# Inputs

# %%
nfmax = 300         # max frequency for MDC (#samples)
n_iter = 10         # iterations
subsampling = 4     # subsampling of src-recs compared to original data
ivsmdd = 758        # index of VS to use in selection of data for MDD

inputfile_aux = os.environ["STORE_PATH"] + '3DMarchenko_auxiliary_2.npz'

# %%
# Load input
inputdata_aux = np.load(inputfile_aux)

# Receivers
r = inputdata_aux['recs'][::subsampling].T
nr = r.shape[1]
dr = r[0,1]-r[0,0]

# Sources
s = inputdata_aux['srcs'][::subsampling].T
ns = s.shape[1]
ds = s[0,1]-s[0,0]

# Virtual points
vsz = 650
nvsx = 71
dvsx = 20
ovsx = 200
nvsy = 41
dvsy = 20
ovsy = 200
nvs = nvsx * nvsy
vsy = np.arange(nvsy) * dvsy + ovsy 
vsx = np.arange(nvsx) * dvsx + ovsx 
VSX, VSY = np.meshgrid(vsx, vsy, indexing='ij')

# Time axis
ot, dt, nt = 0, 2.5e-3, 601
t = np.arange(nt)*dt

# Density model
rho = inputdata_aux['rho']
z, x, y = inputdata_aux['z'], inputdata_aux['x'], inputdata_aux['y']

# Display geometry
fig, ax = plt.subplots(1, 1, sharey=True, figsize=(13, 11))      
ax.scatter(r[0], r[1], marker='.', s=200, c='r', edgecolors='k', label='Srcs-Recs')
ax.scatter(VSX.ravel(), VSY.ravel(), marker='.', s=500, c='g', edgecolors='k', label='VS')
ax.scatter(VSX.ravel()[ivsmdd:ivsmdd+1], 
           VSY.ravel()[ivsmdd:ivsmdd+1], marker='.', s=500, 
           c='y', edgecolors='k', label='VS plot')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Geometry')
plt.legend()
plt.show()

fig, ax1 = plt.subplots(1, 1, figsize=(13, 6))
ax1.imshow(rho[np.argmin(np.abs(y-VSY.ravel()[ivsmdd]))].T, cmap='gray', vmin=1000, vmax=5000,
           extent = (x[0], x[-1], z[-1], z[0]))
ax1.axhline(r[2, 0], color='b', lw=4)
ax1.axhline(s[2, 0], color='r', linestyle='--', lw=4)
ax1.scatter(vsx, vsz * np.ones(nvsx), marker='.', s=400, c='g', edgecolors='k')
ax1.scatter(VSX.ravel()[ivsmdd], vsz * np.ones(1), marker='.', s=500, c='y', edgecolors='k')
ax1.axis('tight')
ax1.set_xlabel('x [m]')
ax1.set_ylabel('z [m]')
ax1.set_xlim(x[0], x[-1]);

# %%
Gplus = da.from_zarr(os.environ["STORE_PATH"] + 'Gplus_sub%d.zarr' % subsampling)
Gminus = da.from_zarr(os.environ["STORE_PATH"] + 'Gminus_sub%d.zarr' % subsampling)
Gdir = da.from_zarr(os.environ["STORE_PATH"] + 'Gdir_sub%d.zarr' % subsampling)
Grtm = da.from_zarr(os.environ["STORE_PATH"] + 'Grtm_sub%d.zarr' % subsampling)

# %% [markdown]
# Pad operator and data at zero time and choose single VS

# %%
Grtm = Grtm[:,:,ivsmdd]
Gminus = Gminus[:,:,ivsmdd]
Grtm = da.concatenate((da.zeros((nt-1, nr)), Grtm), axis=0)
Gminus = da.concatenate((da.zeros((nt-1, nr)), Gminus), axis=0)

Grtm = client.persist(Grtm)
Gminus = client.persist(Gminus)

# %% [markdown]
# Prepare MDC kernel

# %%
nchunks = [max(nfmax // nworkers, 1), nr, nvs]

Gdir = da.concatenate((da.zeros((nt-1, nr, nvs)), Gdir), axis=0)
Gdir = Gdir.rechunk(2*nt-1, Gdir.chunks[1][0], Gdir.chunks[2][0])
Gdir = da.fft.rfft(Gdir, 2*nt-1, axis=0)
Gdir = Gdir[:nfmax]
Gdir = Gdir.rechunk(nchunks)
Gdir = client.persist(Gdir)  
client.rebalance(Gdir)

# %%
Gplus = da.concatenate((da.zeros((nt-1, nr, nvs)), Gplus), axis=0)
Gplus = Gplus.rechunk(2*nt-1, Gplus.chunks[1][0], Gplus.chunks[2][0])
Gplus = da.fft.rfft(Gplus, 2*nt-1, axis=0)
Gplus = Gplus[:nfmax]
Gplus = Gplus.rechunk(nchunks)
Gplus = client.persist(Gplus)  
client.rebalance(Gplus)

# %%
Gdir
# Out:
# dask.array<rechunk-merge, shape=(300, 2451, 2911), dtype=complex128, chunksize=(33, 2451, 2911)>

# %% [markdown]
# Define modelling operator

# %%
Gdirop = \
    pylops_distributed.waveeqprocessing.MDC(Gdir, nt=2*nt-1, 
                                            nv=1, dt=dt, 
                                            dr=dvsx*dvsy, 
                                            twosided=True)
ddottest(Gdirop, (2*nt-1)*nr, (2*nt-1)*nvs, 
         chunks=(Gdirop.shape[0], Gdirop.shape[1]),
         complexflag=3, verb=True);
# Out:
# Dot test passed, v^T(Opu)=-50.468284 - u^T(Op^Tv)=-50.468284

# %%
Gplusop = \
    pylops_distributed.waveeqprocessing.MDC(Gplus, nt=2*nt-1, 
                                            nv=1, dt=dt, 
                                            dr=dvsx*dvsy, 
                                            twosided=True)
ddottest(Gplusop, (2*nt-1)*nr, (2*nt-1)*nvs, 
         chunks=(Gplusop.shape[0], Gplusop.shape[1]),
         complexflag=3, verb=True);
# Out:
# Dot test passed, v^T(Opu)=-185621.581531 - u^T(Op^Tv)=-185621.581531

# %% [markdown]
# Compute adjoint and inverse

# %%
Radj = Gdirop.H * Grtm.flatten()
Radj = Radj.reshape(2*nt-1, nvs)
Radj = Radj.compute()

# %%
Rinv = dcgls(Gplusop, Gminus.ravel(), niter=10, compute=False)[0]
Rinv = Rinv.reshape(2*nt-1, nvs)
Rinv = Rinv.compute()

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(10, 6))
ax1.imshow(Radj, aspect='auto',interpolation='nearest', cmap='gray', 
           vmin=-0.05*Radj.max(), vmax=0.05*Radj.max(),
           extent=(0, nvs, t.max(), -t.max()))
ax1.set_title('Radj', fontsize=15)
ax1.set_ylabel('t')
ax1.set_xlim(nvs//2-100, nvs//2+100);
ax1.set_ylim(0.5, 0);

fig, ax1 = plt.subplots(1, 1, figsize=(10, 6))
ax1.imshow(Rinv, aspect='auto',interpolation='nearest', cmap='gray', 
           vmin=-0.2*Rinv.max(), vmax=0.2*Rinv.max(),
           extent=(0, nvs, t.max(), -t.max()))
ax1.set_title('Rinv', fontsize=15)
ax1.set_ylabel('t')
ax1.set_xlim(ivsmdd-100, ivsmdd+100);
ax1.set_ylim(0.5, 0);
